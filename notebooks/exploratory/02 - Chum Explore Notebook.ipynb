# %%
import psycopg2
import pandas as pd
DBNAME = "opportunity_youth"
conn = psycopg2.connect(dbname=DBNAME)
pd.read_sql("SELECT * FROM pums_2017 LIMIT 10;", conn)
# Out:
#   rt       serialno division sporder   puma region  st   adjinc  pwgtp  agep  \
# 0  P  2013000000006        9      01  11606      4  53  1061971   27.0  68.0
# 1  P  2013000000006        9      02  11606      4  53  1061971   22.0  66.0
# 2  P  2013000000012        9      01  10100      4  53  1061971   22.0  72.0
# 3  P  2013000000012        9      02  10100      4  53  1061971   19.0  64.0
# 4  P  2013000000038        9      01  11505      4  53  1061971    4.0  52.0
# 5  P  2013000000038        9      02  11505      4  53  1061971    4.0  51.0
# 6  P  2013000000038        9      03  11505      4  53  1061971    7.0  18.0
# 7  P  2013000000070        9      01  10400      4  53  1061971   15.0  59.0
# 8  P  2013000000070        9      02  10400      4  53  1061971   18.0  56.0
# 9  P  2013000000082        9      01  11615      4  53  1061971   90.0  40.0
#
#    ...  pwgtp71  pwgtp72 pwgtp73 pwgtp74 pwgtp75 pwgtp76 pwgtp77 pwgtp78  \
# 0  ...     53.0     24.0    39.0    24.0     7.0    27.0     8.0    46.0
# 1  ...     49.0     21.0    38.0    20.0     7.0    25.0     8.0    41.0
# 2  ...     24.0     22.0    25.0     7.0    21.0    35.0     6.0    22.0
# 3  ...     21.0     18.0    19.0     7.0    17.0    29.0     6.0    19.0
# 4  ...      4.0      1.0     2.0     8.0     8.0     1.0     4.0     6.0
# 5  ...      4.0      1.0     1.0     8.0     7.0     1.0     4.0     7.0
# 6  ...      5.0      2.0     3.0    14.0    12.0     2.0     8.0    13.0
# 7  ...     26.0     14.0    14.0    26.0    15.0    16.0    33.0    16.0
# 8  ...     27.0     15.0    16.0    30.0    14.0    18.0    38.0    17.0
# 9  ...    119.0    152.0    33.0    30.0   100.0    77.0   115.0    85.0
#
#   pwgtp79 pwgtp80
# 0    25.0    50.0
# 1    22.0    47.0
# 2     6.0    37.0
# 3     6.0    29.0
# 4     1.0     4.0
# 5     2.0     4.0
# 6     3.0     6.0
# 7    15.0    15.0
# 8    17.0    14.0
# 9   114.0    29.0
#
# [10 rows x 286 columns]

# %%
pd.read_sql("SELECT division FROM pums_2017 LIMIT 10;", conn)
# Out:
#   division
# 0        9
# 1        9
# 2        9
# 3        9
# 4        9
# 5        9
# 6        9
# 7        9
# 8        9
# 9        9

# %%
pd.read_sql("""PRAGMA table_info(pums_2017);""", conn)
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /opt/anaconda3/envs/oy-env/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1585         try:
# -> 1586             cur.execute(*args, **kwargs)
#    1587             return cur
#
# SyntaxError: syntax error at or near "PRAGMA"
# LINE 1: PRAGMA table_info(pums_2017);
#         ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-8-6c58cce7a0b2> in <module>
# ----> 1 pd.read_sql("""PRAGMA table_info(pums_2017);""", conn)
#
# /opt/anaconda3/envs/oy-env/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     404
#     405     if isinstance(pandas_sql, SQLiteDatabase):
# --> 406         return pandas_sql.read_query(
#     407             sql,
#     408             index_col=index_col,
#
# /opt/anaconda3/envs/oy-env/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1631
#    1632         args = _convert_params(sql, params)
# -> 1633         cursor = self.execute(*args)
#    1634         columns = [col_desc[0] for col_desc in cursor.description]
#    1635
#
# /opt/anaconda3/envs/oy-env/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1596
#    1597             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1598             raise ex from exc
#    1599
#    1600     @staticmethod
#
# DatabaseError: Execution failed on sql 'PRAGMA table_info(pums_2017);': syntax error at or near "PRAGMA"
# LINE 1: PRAGMA table_info(pums_2017);
#         ^

# %%
conn.close()
